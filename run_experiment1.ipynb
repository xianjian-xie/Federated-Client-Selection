# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/MyDrive/CapstoneProject/Federated-Client-Selection")

# %%
cd src
# Out:
# /content/gdrive/MyDrive/CapstoneProject/Federated-Client-Selection/src

# %%
# !ls
# Out:
# ceshi.py	  data.py		process.py
# config_choice.md  datasets		__pycache__
# config.py	  day2022_07_07_1.log	summary.py
# config.yml	  day2022_07_21_1.log	test_classifier_fl.py
# cs1-time.txt	  day2022_07_22_1.log	test_classifier.py
# cs1.txt		  log			test.py
# cs2-20.txt	  logger.py		train_classifier_fl_cs1.py
# cs2.txt		  log.txt		train_classifier_fl_cs2.py
# cs3ceshi.txt	  make.py		train_classifier_fl_cs3.py
# cs3.txt		  metrics		train_classifier_fl_cs4.py
# cs4.txt		  models		train_classifier_fl_cs5.py
# cs5-400epoch.txt  modules		train_classifier_fl_cs6.py
# cs5.txt		  multiple_cluster.txt	train_classifier_fl.py
# cs6-400epoch.txt  output		train_classifier.py
# cs6.txt		  output_record.md	utils.py
# cs_all.txt	  plot.py
# data		  printlog.py

# %%
# !pip install pyyaml

# !pip install torchvision

# !pip install scipy

# !pip install tensorboard

# !pip install anytree

# !pip install tqdm

# !pip install wheel

# !pip install pandas

# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 432 kB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install -U PyYAML
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 596 kB 6.7 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install config-file
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install -U jax==0.3.10
# !pip install -U jaxlib==0.3.10
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 939 kB 6.7 MB/s
# ...
#   Created wheel for jax: filename=jax-0.3.10-py3-none-any.whl size=1088066 sha256=055e6247dc3410c8138e830c08078169ee29281be30120c4a833bb1092d57aa4
#   Stored in directory: /root/.cache/pip/wheels/1c/05/23/36730377cd7311156f1e5eb5e7c683d5cdac1654658c095cc5
# Successfully built jax
# ...
#   Attempting uninstall: jax
#     Found existing installation: jax 0.3.14
#     Uninstalling jax-0.3.14:
#       Successfully uninstalled jax-0.3.14
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 69.0 MB 90 kB/s
# ...
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.3.14+cuda11.cudnn805
#     Uninstalling jaxlib-0.3.14+cuda11.cudnn805:
#       Successfully uninstalled jaxlib-0.3.14+cuda11.cudnn805
# ...

# %%
# !python train_classifier_fl_cs1.py --control_name CIFAR10_wresnet28x2_100_0.10_iid_target-dataset_channel-0.3_valid-mask-cluster_diff --pin_memory True --num_workers 0 --init_seed 0 --num_experiments 1 --log_interval 0.25 --device cuda --resume_mode 0 --verbose False
# Out:
# jin zhe li 1
# jin zhe li 2
# kaishi cfg is {'control': {'data_name': 'CIFAR10', 'model_name': 'wresnet28x2', 'num_clients': '100', 'active_rate': '0.1', 'data_split_mode': 'iid', 'data_poison_method': 'target', 'adversarial_ratio': 'local-0.1', 'selection_method': 'valid-acc-cluster', 'diff_option': 'no-diff'}, 'pin_memory': True, 'num_workers': 0, 'init_seed': 0, 'num_experiments': 1, 'log_interval': 0.25, 'device': 'cuda', 'world_size': 1, 'resume_mode': 1, 'verbose': True}
# ...

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/CapstoneProject/Federated-Client-Selection/src'
