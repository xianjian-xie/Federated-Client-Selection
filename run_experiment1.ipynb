# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/MyDrive/CapstoneProject/Federated-Client-Selection")

# %%
cd src
# Out:
# /content/gdrive/MyDrive/CapstoneProject/Federated-Client-Selection/src

# %%
# !ls
# Out:
# config.py	  data	       __pycache__
# config.yml	  data.py      summary.py
# cs1-time.txt	  datasets     test_classifier_fl.py
# cs1.txt		  log	       test_classifier.py
# cs2-20.txt	  logger.py    test.py
# cs2.txt		  log.txt      train_classifier_fl_cs1.py
# cs3ceshi.txt	  make.py      train_classifier_fl_cs2.py
# cs3.txt		  metrics      train_classifier_fl_cs3.py
# cs4.txt		  models       train_classifier_fl_cs4.py
# cs5-400epoch.txt  modules      train_classifier_fl_cs5.py
# cs5.txt		  output       train_classifier_fl_cs6.py
# cs6-400epoch.txt  plot.py      train_classifier_fl.py
# cs6.txt		  printlog.py  train_classifier.py
# cs_all.txt	  process.py   utils.py

# %%
# !pip install pyyaml

# !pip install torchvision

# !pip install scipy

# !pip install tensorboard

# !pip install anytree

# !pip install tqdm

# !pip install wheel

# !pip install pandas

# !pip install -U scikit-learn
# Out:
# ...
#      |████████████████████████████████| 41 kB 714 kB/s
# ...

# %%
# !pip install -U PyYAML
# Out:
# ...
#      |████████████████████████████████| 596 kB 25.7 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install config-file

# %%
# !python train_classifier_fl_cs2.py --control_name CIFAR10_wresnet28x2_100_0.100_iid --pin_memory True --num_workers 0 --init_seed 0 --num_experiments 1 --log_interval 0.25 --device cuda --resume_mode 1 --verbose False
# Out:
# jin process args
# Experiment: 0_CIFAR10_wresnet28x2_100_0.100_iid
# **********************day2022_05_07_1***********************
# fetching data CIFAR10...
# data ready
# cfg model tag is 0_CIFAR10_wresnet28x2_100_0.100_iid
# jin resume 1
# jin le else
# Not exists model tag: 0_CIFAR10_wresnet28x2_100_0.100_iid, start from scratch
# shedingweihuai tensor(0)
# shedingweihuai tensor(1)
# shedingweihuai tensor(2)
# shedingweihuai tensor(3)
# shedingweihuai tensor(4)
# shedingweihuai tensor(5)
# shedingweihuai tensor(6)
# shedingweihuai tensor(7)
# shedingweihuai tensor(8)
# shedingweihuai tensor(9)
# shedingweihuai tensor(10)
# shedingweihuai tensor(11)
# shedingweihuai tensor(12)
# shedingweihuai tensor(13)
# shedingweihuai tensor(14)
# shedingweihuai tensor(15)
# shedingweihuai tensor(16)
# shedingweihuai tensor(17)
# shedingweihuai tensor(18)
# shedingweihuai tensor(19)
# client id1 [16, 70, 1, 12, 75, 41, 83, 9, 43, 45]
# thegehuairenjinlaile tensor(16)
# ...

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/CapstoneProject/Federated-Client-Selection/src'
